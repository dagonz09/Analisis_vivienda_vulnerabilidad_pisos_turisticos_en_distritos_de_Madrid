# %%
#pip install pandas
#pip install sweetviz
#pip install seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\danie\onedrive\escritorio\unir\.venv-2\lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\danie\onedrive\escritorio\unir\.venv-2\lib\site-packages (from pandas) (2.4.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\danie\onedrive\escritorio\unir\.venv-2\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\danie\onedrive\escritorio\unir\.venv-2\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\danie\onedrive\escritorio\unir\.venv-2\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from pathlib import Path

# %%
RAIZ  = Path.cwd().parent
IVTA = RAIZ / "data" / "IVTA" / "informe__IVTA_Distritos_2020-2024.csv"
ivta_df = pd.read_csv(IVTA, sep=";")
mediaMadrid_ivta = ivta_df["Indice de Vulnerabilidad Territorial Agregado - media ciudad"]
mediaMadrid_Vulnerabilidad_Bienestar = ivta_df["Índice de Vulnerabilidad Bienestar Social e Igualdad - media ciudad"]
ivta_df = ivta_df[["Nombre distrito", "Fecha datos", "Indice de Vulnerabilidad Territorial Agregado", 
                   "Índice de Vulnerabilidad Bienestar Social e Igualdad"]]

#ivta_df = ivta_df[ivta_df["Nombre distrito"].isin(["Centro", "Villaverde", "Tetuán"])]

ivta_df["Indice de Vulnerabilidad Territorial Agregado"] = ivta_df["Indice de Vulnerabilidad Territorial Agregado"].str.replace(",", ".").astype(float)
ivta_df["Índice de Vulnerabilidad Bienestar Social e Igualdad"] = ivta_df["Índice de Vulnerabilidad Bienestar Social e Igualdad"].str.replace(",", ".").astype(float)

ivta_df = ivta_df.rename(columns={
    "Nombre distrito": "Distrito",
    "Fecha datos": "Año",
})
ivta_df = ivta_df[ivta_df["Distrito"] != "Ciudad de Madrid"]

print(ivta_df.to_string())
# Out:
#                 Distrito   Año  Indice de Vulnerabilidad Territorial Agregado  Índice de Vulnerabilidad Bienestar Social e Igualdad
# 0                 Centro  2020                                           5.53                                                  5.98
# 1             Arganzuela  2020                                           3.84                                                  4.28
# 2                 Retiro  2020                                           3.85                                                  4.11
# 3              Salamanca  2020                                           4.24                                                  4.62
# 4              Chamartín  2020                                           4.27                                                  4.36
# 5                 Tetuán  2020                                           5.34                                                  4.53
# 6               Chamberí  2020                                           5.30                                                  4.25
# 7    Fuencarral-El Pardo  2020                                           4.15                                                  3.91
# 8        Moncloa-Aravaca  2020                                           3.79                                                  3.97
# 9                 Latina  2020                                           5.01                                                  4.50
# 10           Carabanchel  2020                                           5.74                                                  5.51
# 11                 Usera  2020                                           5.73                                                  5.16
# 12    Puente de Vallecas  2020                                           5.91                                                  6.39
# 13             Moratalaz  2020                                           4.63                                                  5.27
# 14         Ciudad Lineal  2020                                           4.77                                                  4.26
# 15             Hortaleza  2020                                           4.11                                                  3.85
# 16            Villaverde  2020                                           5.66                                                  4.87
# 17     Villa de Vallecas  2020                                           5.32                                                  5.87
# 18             Vicálvaro  2020                                           4.57                                                  5.17
# 19   San Blas-Canillejas  2020                                           4.57                                                  4.36
# 20               Barajas  2020                                           3.73                                                  4.76
# 21                Centro  2021                                           5.57                                                  6.56
# 22            Arganzuela  2021                                           3.81                                                  4.17
# 23                Retiro  2021                                           3.82                                                  4.19
# 24             Salamanca  2021                                           4.24                                                  4.42
# 25             Chamartín  2021                                           3.89                                                  3.93
# 26                Tetuán  2021                                           5.24                                                  4.48
# 27              Chamberí  2021                                           5.56                                                  4.46
# 28   Fuencarral-El Pardo  2021                                           3.80                                                  4.29
# 29       Moncloa-Aravaca  2021                                           3.78                                                  3.99
# 30                Latina  2021                                           4.78                                                  4.46
# 31           Carabanchel  2021                                           5.84                                                  5.55
# 32                 Usera  2021                                           5.97                                                  5.21
# 33    Puente de Vallecas  2021                                           6.28                                                  6.68
# 34             Moratalaz  2021                                           4.81                                                  5.63
# 35         Ciudad Lineal  2021                                           4.42                                                  4.22
# 36             Hortaleza  2021                                           4.04                                                  3.64
# 37            Villaverde  2021                                           5.66                                                  4.86
# 38     Villa de Vallecas  2021                                           5.44                                                  5.62
# 39             Vicálvaro  2021                                           4.92                                                  4.96
# 40   San Blas-Canillejas  2021                                           4.48                                                  4.21
# 41               Barajas  2021                                           3.65                                                  4.47
# 42                Centro  2022                                           5.78                                                  6.61
# 43            Arganzuela  2022                                           3.88                                                  4.03
# 44                Retiro  2022                                           3.71                                                  4.23
# 45             Salamanca  2022                                           4.33                                                  4.43
# 46             Chamartín  2022                                           3.90                                                  4.03
# 47                Tetuán  2022                                           4.89                                                  4.09
# 48              Chamberí  2022                                           5.69                                                  4.20
# 49   Fuencarral-El Pardo  2022                                           3.80                                                  4.01
# 50       Moncloa-Aravaca  2022                                           3.67                                                  3.81
# 51                Latina  2022                                           4.91                                                  4.86
# 52           Carabanchel  2022                                           5.44                                                  4.79
# 53                 Usera  2022                                           5.90                                                  5.58
# 54    Puente de Vallecas  2022                                           6.22                                                  6.60
# 55             Moratalaz  2022                                           5.06                                                  6.24
# 56         Ciudad Lineal  2022                                           4.24                                                  4.12
# 57             Hortaleza  2022                                           4.08                                                  3.80
# 58            Villaverde  2022                                           5.80                                                  5.18
# 59     Villa de Vallecas  2022                                           5.36                                                  5.48
# 60             Vicálvaro  2022                                           4.91                                                  5.06
# 61   San Blas-Canillejas  2022                                           4.59                                                  4.01
# 62               Barajas  2022                                           3.87                                                  4.83
# 63                Centro  2023                                           5.66                                                  6.17
# 64            Arganzuela  2023                                           3.99                                                  4.68
# 65                Retiro  2023                                           3.77                                                  4.36
# 66             Salamanca  2023                                           4.29                                                  4.30
# 67             Chamartín  2023                                           3.99                                                  4.21
# 68                Tetuán  2023                                           4.81                                                  3.86
# 69              Chamberí  2023                                           5.53                                                  4.17
# 70   Fuencarral-El Pardo  2023                                           3.79                                                  3.95
# 71       Moncloa-Aravaca  2023                                           3.73                                                  4.08
# 72                Latina  2023                                           4.86                                                  4.54
# 73           Carabanchel  2023                                           5.41                                                  4.79
# 74                 Usera  2023                                           5.76                                                  5.42
# 75    Puente de Vallecas  2023                                           6.37                                                  7.13
# 76             Moratalaz  2023                                           5.21                                                  6.75
# 77         Ciudad Lineal  2023                                           4.27                                                  3.89
# 78             Hortaleza  2023                                           4.12                                                  3.86
# 79            Villaverde  2023                                           5.76                                                  5.02
# 80     Villa de Vallecas  2023                                           5.29                                                  5.12
# 81             Vicálvaro  2023                                           4.87                                                  4.79
# 82   San Blas-Canillejas  2023                                           4.64                                                  4.08
# 83               Barajas  2023                                           3.88                                                  4.83
# 84                Centro  2024                                           5.89                                                  6.45
# 85            Arganzuela  2024                                           4.11                                                  4.98
# 86                Retiro  2024                                           3.87                                                  4.77
# 87             Salamanca  2024                                           4.09                                                  3.55
# 88             Chamartín  2024                                           3.97                                                  4.36
# 89                Tetuán  2024                                           4.69                                                  3.78
# 90              Chamberí  2024                                           5.59                                                  4.11
# 91   Fuencarral-El Pardo  2024                                           3.93                                                  4.10
# 92       Moncloa-Aravaca  2024                                           3.65                                                  3.62
# 93                Latina  2024                                           4.97                                                  4.46
# 94           Carabanchel  2024                                           5.44                                                  4.71
# 95                 Usera  2024                                           5.93                                                  5.53
# 96    Puente de Vallecas  2024                                           6.42                                                  6.84
# 97             Moratalaz  2024                                           5.08                                                  5.95
# 98         Ciudad Lineal  2024                                           4.34                                                  4.05
# 99             Hortaleza  2024                                           4.09                                                  4.17
# 100           Villaverde  2024                                           5.64                                                  4.81
# 101    Villa de Vallecas  2024                                           5.23                                                  5.58
# 102            Vicálvaro  2024                                           4.72                                                  4.99
# 103  San Blas-Canillejas  2024                                           4.57                                                  4.06
# 104              Barajas  2024                                           3.78                                                  5.13

# %%
precioVivienda = RAIZ / "data" / "precio vivienda" / "Ayuntamiento_vivienda_distrito_m2_2020-2025.csv"
precioVivienda_df = pd.read_csv(precioVivienda, sep=";", skiprows=5, thousands=".", decimal=",")
precioVivienda_df = precioVivienda_df[["Año", "Distrito", "Euros/m2"]]

#precioVivienda_df = precioVivienda_df[precioVivienda_df["Distrito"].isin(["01. Centro", "17. Villaverde", "06. Tetuán"])]
precioVivienda_df = precioVivienda_df[precioVivienda_df["Año"].isin([2020, 2021, 2022, 2023, 2024])]
precioVivienda_df["Año"] = precioVivienda_df["Año"].astype(int)
precioVivienda_df["Distrito"] = precioVivienda_df["Distrito"].str.replace(r"^\d+\.\s*", "", regex=True)

precioVivienda_df = precioVivienda_df[precioVivienda_df["Distrito"] != "Ciudad de Madrid"]

precioVivienda_df = precioVivienda_df.rename(columns={
    "Euros/m2": "Precio vivienda (€/m²)",
})
precioVivienda_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 105 entries, 1 to 109
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Año                     105 non-null    int64
#  1   Distrito                105 non-null    str
#  2   Precio vivienda (€/m²)  105 non-null    float64
# dtypes: float64(1), int64(1), str(1)
# memory usage: 3.3 KB

# %%
precioAlquiler = RAIZ / "data" / "precio vivienda - alquiler" / "Precios_alquiler_estadísticas_año-distrito.csv"
precioAlquiler_df = pd.read_csv(precioAlquiler, sep=";", skiprows=4)
precioAlquiler_df["Año"] = pd.to_numeric(precioAlquiler_df["Año"], errors="coerce").astype("Int64")

cols_int = ["Número de viviendas en alquiler", "Número de viviendas en alquiler.1", "Número de viviendas en alquiler.2"]

for col in cols_int:
    precioAlquiler_df[col] = precioAlquiler_df[col].str.replace(".", "", regex=False)
    precioAlquiler_df[col] = pd.to_numeric(
        precioAlquiler_df[col].str.replace(",", ".", regex=False),
        errors="coerce"
    )

for col in cols_int:
    precioAlquiler_df[col] = pd.to_numeric(precioAlquiler_df[col], errors="coerce")

precioAlquiler_df = precioAlquiler_df.dropna(subset=cols_int)

precioAlquiler_df[cols_int] = precioAlquiler_df[cols_int].astype(int)

cols_float = ["Renta media vivienda colectiva (€/m2.mes)", "Renta media vivienda unifamiliar (€/m2.mes)"]

for col in cols_float:
    precioAlquiler_df[col] = precioAlquiler_df[col].str.replace(".", "", regex=False)
    precioAlquiler_df[col] = pd.to_numeric(
        precioAlquiler_df[col].str.replace(",", ".", regex=False),
        errors="coerce"
    )

#precioAlquiler_df = precioAlquiler_df[precioAlquiler_df["Distrito"].isin(["01. Centro", "17. Villaverde", "06. Tetuán"])]

precioAlquiler_df = precioAlquiler_df[["Año", "Distrito", "Número de viviendas en alquiler", "Número de viviendas en alquiler.1", "Número de viviendas en alquiler.2",
                                       "Renta media vivienda colectiva (€/m2.mes)", "Renta media vivienda unifamiliar (€/m2.mes)"]]

precioAlquiler_df["Distrito"] = precioAlquiler_df["Distrito"].str.replace(r"^\d+\.\s*", "", regex=True)

precioAlquiler_df = precioAlquiler_df[precioAlquiler_df["Distrito"] != "Ciudad de Madrid"]


precioAlquiler_df = precioAlquiler_df.rename(columns={
    "Número de viviendas en alquiler": "Nº viviendas en alquiler",
    "Número de viviendas en alquiler.1": "Nº viviendas en alquiler colectiva",
    "Número de viviendas en alquiler.2": "Nº viviendas en alquiler unifamiliar",
    "Renta media vivienda colectiva (€/m2.mes)": "Renta vivienda colectiva (€/m².mes)",
    "Renta media vivienda unifamiliar (€/m2.mes)": "Renta vivienda unifamiliar (€/m².mes)",
})

precioAlquiler_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 105 entries, 2 to 110
# Data columns (total 7 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Año                                    105 non-null    Int64
#  1   Distrito                               105 non-null    str
#  2   Nº viviendas en alquiler               105 non-null    int64
#  3   Nº viviendas en alquiler colectiva     105 non-null    int64
#  4   Nº viviendas en alquiler unifamiliar   105 non-null    int64
#  5   Renta vivienda colectiva (€/m².mes)    105 non-null    float64
#  6   Renta vivienda unifamiliar (€/m².mes)  105 non-null    float64
# dtypes: Int64(1), float64(2), int64(3), str(1)
# memory usage: 6.7 KB

# %%
precioAlquiler_meses = RAIZ / "data" / "precio vivienda - alquiler" / "precio_alquiler_distrito_mes.csv"
precioAlquiler_meses_df = pd.read_csv(precioAlquiler_meses, sep=",", skiprows=4)

#precioAlquiler_meses_df = precioAlquiler_meses_df[precioAlquiler_meses_df["Distrito"].isin(["01. Centro", "17. Villaverde", "06. Tetuán"])]

cols_float = ["Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio", "Julio", "Agosto", "Septiembre", "Octubre", "Noviembre", "Diciembre"]

for col in cols_float:
    precioAlquiler_meses_df[col] = pd.to_numeric(
        precioAlquiler_meses_df[col].str.replace(",", ".", regex=False),
        errors="coerce"
    )


precioAlquiler_meses_df["Precio alquiler €/m² media del año"] = precioAlquiler_meses_df[["Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio", "Julio", "Agosto", "Septiembre", "Octubre", "Noviembre", "Diciembre"]].mean(axis=1)

precioAlquiler_meses_df = precioAlquiler_meses_df[["Año", "Distrito", "Precio alquiler €/m² media del año"]]

precioAlquiler_meses_df["Año"] = precioAlquiler_meses_df["Año"].astype(int)
precioAlquiler_meses_df["Distrito"] = precioAlquiler_meses_df["Distrito"].str.replace(r"^\d+\.\s*", "", regex=True)
precioAlquiler_meses_df = precioAlquiler_meses_df[precioAlquiler_meses_df["Distrito"] != "Ciudad de Madrid"]

precioAlquiler_meses_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 105 entries, 1 to 109
# Data columns (total 3 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Año                                 105 non-null    int64
#  1   Distrito                            105 non-null    str
#  2   Precio alquiler €/m² media del año  105 non-null    float64
# dtypes: float64(1), int64(1), str(1)
# memory usage: 3.3 KB

# %%
#DESESTIMADO!!

encuestaOcupacion = RAIZ / "data" / "apartamentos turisticos" / "Encuesta ocupación hotelera.csv"
encuestaOcupacion_df = pd.read_csv(encuestaOcupacion, sep=";", skiprows=5)

encuestaOcupacion_df["Año"] = encuestaOcupacion_df["Año"].astype(int)

encuestaOcupacion_df = encuestaOcupacion_df[encuestaOcupacion_df["Año"].isin([2020, 2021, 2022, 2023, 2024])]
encuestaOcupacion_df = encuestaOcupacion_df[["Año", "Número plazas estimadas", "Número apartamentos estimados"]]

cols_float = ["Número plazas estimadas", "Número apartamentos estimados"]

for col in cols_float:
    encuestaOcupacion_df[col] = encuestaOcupacion_df[col].str.replace(".", "", regex=False)
    encuestaOcupacion_df[col] = pd.to_numeric(
        encuestaOcupacion_df[col].str.replace(",", ".", regex=False),
        errors="coerce"
    )

encuestaOcupacion_df.head(30)
# Out:
#      Año  Número plazas estimadas  Número apartamentos estimados
# 10  2020                  5929.33                        2289.75
# 11  2021                  9202.08                        3452.17
# 12  2022                 10586.42                        3795.58
# 13  2023                 11710.67                        4280.00
# 14  2024                 11491.00                        4179.67

# %%
apartamentosTuristicos = RAIZ / "data" / "apartamentos turisticos" / "apartamentos turísticos_2020-2024_distri_ establecimientos-plazas.csv"
apartamentosTuristicos_df = pd.read_csv(apartamentosTuristicos, sep=";", skiprows=4, thousands=".")

#apartamentosTuristicos_df = apartamentosTuristicos_df[apartamentosTuristicos_df["Distrito"].isin(["01. Centro", "17. Villaverde", "06. Tetuán"])]

apartamentosTuristicos_df = apartamentosTuristicos_df[["Año", "Distrito", "Establecimientos", "Plazas"]]

apartamentosTuristicos_df["Año"] = apartamentosTuristicos_df["Año"].astype(int)
apartamentosTuristicos_df["Establecimientos"] = apartamentosTuristicos_df["Establecimientos"].astype(int)
apartamentosTuristicos_df["Plazas"] = apartamentosTuristicos_df["Plazas"].astype(int)
apartamentosTuristicos_df["Distrito"] = apartamentosTuristicos_df["Distrito"].str.replace(r"^\d+\.\s*", "", regex=True)

apartamentosTuristicos_df = apartamentosTuristicos_df[apartamentosTuristicos_df["Año"].isin([2020, 2021, 2022, 2023, 2024])]


apartamentosTuristicos_df = apartamentosTuristicos_df.rename(columns={
    "Establecimientos": "Establecimientos turisticos",
    "Plazas": "Plazas en sstablecimientos turisticos",
})

apartamentosTuristicos_df = apartamentosTuristicos_df[apartamentosTuristicos_df["Distrito"] != "Ciudad de Madrid"]

apartamentosTuristicos_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 105 entries, 1 to 109
# Data columns (total 4 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Año                                    105 non-null    int64
#  1   Distrito                               105 non-null    str
#  2   Establecimientos turisticos            105 non-null    int64
#  3   Plazas en sstablecimientos turisticos  105 non-null    int64
# dtypes: int64(3), str(1)
# memory usage: 4.1 KB

# %%
poblacion = RAIZ / "data" / "poblacion distrito" / "poblacion-distrito-barrio_2018-2024.csv"
poblacion_df = pd.read_csv(poblacion, sep=";", thousands=".")

poblacion_df["barrio"] = poblacion_df["barrio"].str.strip()
poblacion_df["distrito"] = poblacion_df["distrito"].str.strip()


poblacion_df = poblacion_df[poblacion_df["distrito"] == poblacion_df["barrio"]]
#poblacion_df = poblacion_df[poblacion_df["barrio"].isin(["Centro", "17. Villaverde", "06. Tetuán"])]

poblacion_df["Año"] = poblacion_df["fecha"].str.extract(r"(\d{4})").astype(int)
poblacion_df = poblacion_df[poblacion_df["distrito"] == poblacion_df["barrio"]]

poblacion_df = poblacion_df.rename(columns={
    "distrito": "Distrito",
})
poblacion_df["Distrito"] = poblacion_df["Distrito"].replace("Todos", "Ciudad de Madrid")

poblacion_df = poblacion_df[["Año", "Distrito", "num_personas"]]
poblacion_df = poblacion_df[poblacion_df["Año"].isin([2020, 2021, 2022, 2023, 2024])]

poblacion_df = poblacion_df[poblacion_df["Distrito"] != "Ciudad de Madrid"]

poblacion_df.info()
#print(poblacion_df.to_string())
# Out:
# <class 'pandas.DataFrame'>
# Index: 105 entries, 0 to 632
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Año           105 non-null    int64
#  1   Distrito      105 non-null    str
#  2   num_personas  105 non-null    int64
# dtypes: int64(2), str(1)
# memory usage: 3.3 KB

# %%
#apartamentosTuristicos_df, encuestaOcupacion_df, precioAlquiler_df, precioVivienda_df, ivta_df
df_total = (
    apartamentosTuristicos_df
    .merge(precioAlquiler_df, on=["Año", "Distrito"], how="inner")
    .merge(precioVivienda_df, on=["Año", "Distrito"], how="inner")
    .merge(ivta_df, on=["Año", "Distrito"], how="inner")
    .merge(precioAlquiler_meses_df, on=["Año", "Distrito"], how="inner")
    .merge(poblacion_df, on=["Año", "Distrito"], how="inner")
)


#df_total = pd.concat([apartamentosTuristicos_df, precioAlquiler_df, precioVivienda_df, ivta_df], axis=1)

corr = df_total.corr(numeric_only=True)
#print(corr)
df_total.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 14 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Año                                                   105 non-null    int64
#  1   Distrito                                              105 non-null    str
#  2   Establecimientos turisticos                           105 non-null    int64
#  3   Plazas en sstablecimientos turisticos                 105 non-null    int64
#  4   Nº viviendas en alquiler                              105 non-null    int64
#  5   Nº viviendas en alquiler colectiva                    105 non-null    int64
#  6   Nº viviendas en alquiler unifamiliar                  105 non-null    int64
#  7   Renta vivienda colectiva (€/m².mes)                   105 non-null    float64
#  8   Renta vivienda unifamiliar (€/m².mes)                 105 non-null    float64
#  9   Precio vivienda (€/m²)                                105 non-null    float64
#  10  Indice de Vulnerabilidad Territorial Agregado         105 non-null    float64
#  11  Índice de Vulnerabilidad Bienestar Social e Igualdad  105 non-null    float64
#  12  Precio alquiler €/m² media del año                    105 non-null    float64
#  13  num_personas                                          105 non-null    int64
# dtypes: float64(6), int64(7), str(1)
# memory usage: 11.6 KB

# %%
import sweetviz as sv

reporte = sv.analyze(df_total)
reporte.show_html("reporte_correlaciones.html")
# Out:
# Feature: Año                                 |▋         | [  7%]   00:00 -> (00:00 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: Distrito                            |█▎        | [ 13%]   00:01 -> (00:08 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: Establecimientos turisticos         |██        | [ 20%]   00:02 -> (00:08 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: Plazas en sstablecimientos turisticos|██▋       | [ 27%]   00:06 -> (00:23 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: Nº viviendas en alquiler            |███▎      | [ 33%]   00:08 -> (00:19 left) findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: Nº viviendas en alquiler colectiva  |████      | [ 40%]   00:09 -> (00:15 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: Nº viviendas en alquiler unifamiliar|████▋     | [ 47%]   00:10 -> (00:13 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: Renta vivienda colectiva (€/m².mes) |█████▎    | [ 53%]   00:12 -> (00:10 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: Renta vivienda unifamiliar (€/m².mes)|██████    | [ 60%]   00:13 -> (00:08 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: Precio vivienda (€/m²)              |██████▋   | [ 67%]   00:15 -> (00:07 left) findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: Indice de Vulnerabilidad Territorial Agregado|███████▎  | [ 73%]   00:16 -> (00:05 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: Índice de Vulnerabilidad Bienestar Social e Igualdad|████████  | [ 80%]   00:18 -> (00:04 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: Precio alquiler €/m² media del año  |████████▋ | [ 87%]   00:19 -> (00:03 left)                findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: num_personas                        |█████████▎| [ 93%]   00:21 -> (00:01 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Feature: num_personas                        |██████████| [100%]   00:22 -> (00:00 left)findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# [Step 3/3] Generating associations graph     |          | [  0%]   00:00 -> (? left)    findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:01 -> (00:00 left)
# Report reporte_correlaciones.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
variables = [
    "Indice de Vulnerabilidad Territorial Agregado",
    "Índice de Vulnerabilidad Bienestar Social e Igualdad",
    "Precio vivienda (€/m²)",
    "Renta vivienda unifamiliar (€/m².mes)",
    "Renta vivienda colectiva (€/m².mes)",
    "Nº viviendas en alquiler",
    "Establecimientos turisticos",
    "Plazas en sstablecimientos turisticos",
    "num_personas"
]

corr_pearson = df_total[variables].corr(method="pearson")

print("Pearson")
print(corr_pearson.round(2))
# Out:
# Pearson
#                                                     Indice de Vulnerabilidad Territorial Agregado  \
# Indice de Vulnerabilidad Territorial Agregado                                                1.00
# Índice de Vulnerabilidad Bienestar Social e Igu...                                           0.71
# Precio vivienda (€/m²)                                                                      -0.42
# Renta vivienda unifamiliar (€/m².mes)                                                       -0.20
# Renta vivienda colectiva (€/m².mes)                                                         -0.35
# Nº viviendas en alquiler                                                                     0.09
# Establecimientos turisticos                                                                  0.18
# Plazas en sstablecimientos turisticos                                                        0.08
# num_personas                                                                                 0.22
#
#                                                     Índice de Vulnerabilidad Bienestar Social e Igualdad  \
# Indice de Vulnerabilidad Territorial Agregado                                                    0.71
# Índice de Vulnerabilidad Bienestar Social e Igu...                                               1.00
# Precio vivienda (€/m²)                                                                          -0.38
# Renta vivienda unifamiliar (€/m².mes)                                                           -0.55
# Renta vivienda colectiva (€/m².mes)                                                             -0.34
# Nº viviendas en alquiler                                                                        -0.20
# Establecimientos turisticos                                                                      0.29
# Plazas en sstablecimientos turisticos                                                            0.11
# num_personas                                                                                    -0.06
#
#                                                     Precio vivienda (€/m²)  \
# Indice de Vulnerabilidad Territorial Agregado                        -0.42
# Índice de Vulnerabilidad Bienestar Social e Igu...                   -0.38
# Precio vivienda (€/m²)                                                1.00
# Renta vivienda unifamiliar (€/m².mes)                                 0.18
# Renta vivienda colectiva (€/m².mes)                                   0.97
# Nº viviendas en alquiler                                              0.39
# Establecimientos turisticos                                           0.42
# Plazas en sstablecimientos turisticos                                 0.27
# num_personas                                                         -0.18
#
#                                                     Renta vivienda unifamiliar (€/m².mes)  \
# Indice de Vulnerabilidad Territorial Agregado                                       -0.20
# Índice de Vulnerabilidad Bienestar Social e Igu...                                  -0.55
# Precio vivienda (€/m²)                                                               0.18
# Renta vivienda unifamiliar (€/m².mes)                                                1.00
# Renta vivienda colectiva (€/m².mes)                                                  0.13
# Nº viviendas en alquiler                                                             0.11
# Establecimientos turisticos                                                         -0.40
# Plazas en sstablecimientos turisticos                                               -0.16
# num_personas                                                                         0.16
#
#                                                     Renta vivienda colectiva (€/m².mes)  \
# Indice de Vulnerabilidad Territorial Agregado                                     -0.35
# Índice de Vulnerabilidad Bienestar Social e Igu...                                -0.34
# Precio vivienda (€/m²)                                                             0.97
# Renta vivienda unifamiliar (€/m².mes)                                              0.13
# Renta vivienda colectiva (€/m².mes)                                                1.00
# Nº viviendas en alquiler                                                           0.45
# Establecimientos turisticos                                                        0.50
# Plazas en sstablecimientos turisticos                                              0.36
# num_personas                                                                      -0.15
#
#                                                     Nº viviendas en alquiler  \
# Indice de Vulnerabilidad Territorial Agregado                           0.09
# Índice de Vulnerabilidad Bienestar Social e Igu...                     -0.20
# Precio vivienda (€/m²)                                                  0.39
# Renta vivienda unifamiliar (€/m².mes)                                   0.11
# Renta vivienda colectiva (€/m².mes)                                     0.45
# Nº viviendas en alquiler                                                1.00
# Establecimientos turisticos                                             0.35
# Plazas en sstablecimientos turisticos                                   0.19
# num_personas                                                            0.75
#
#                                                     Establecimientos turisticos  \
# Indice de Vulnerabilidad Territorial Agregado                              0.18
# Índice de Vulnerabilidad Bienestar Social e Igu...                         0.29
# Precio vivienda (€/m²)                                                     0.42
# Renta vivienda unifamiliar (€/m².mes)                                     -0.40
# Renta vivienda colectiva (€/m².mes)                                        0.50
# Nº viviendas en alquiler                                                   0.35
# Establecimientos turisticos                                                1.00
# Plazas en sstablecimientos turisticos                                      0.77
# num_personas                                                              -0.06
#
#                                                     Plazas en sstablecimientos turisticos  \
# Indice de Vulnerabilidad Territorial Agregado                                        0.08
# Índice de Vulnerabilidad Bienestar Social e Igu...                                   0.11
# Precio vivienda (€/m²)                                                               0.27
# Renta vivienda unifamiliar (€/m².mes)                                               -0.16
# Renta vivienda colectiva (€/m².mes)                                                  0.36
# Nº viviendas en alquiler                                                             0.19
# Establecimientos turisticos                                                          0.77
# Plazas en sstablecimientos turisticos                                                1.00
# num_personas                                                                        -0.04
#
#                                                     num_personas
# Indice de Vulnerabilidad Territorial Agregado               0.22
# Índice de Vulnerabilidad Bienestar Social e Igu...         -0.06
# Precio vivienda (€/m²)                                     -0.18
# Renta vivienda unifamiliar (€/m².mes)                       0.16
# Renta vivienda colectiva (€/m².mes)                        -0.15
# Nº viviendas en alquiler                                    0.75
# Establecimientos turisticos                                -0.06
# Plazas en sstablecimientos turisticos                      -0.04
# num_personas                                                1.00

# %%
corr_spearman = df_total[variables].corr(method="spearman")

print("Spearman")
print(corr_spearman.round(2))
# Out:
# Spearman
#                                                     Indice de Vulnerabilidad Territorial Agregado  \
# Indice de Vulnerabilidad Territorial Agregado                                                1.00
# Índice de Vulnerabilidad Bienestar Social e Igu...                                           0.77
# Precio vivienda (€/m²)                                                                      -0.04
# Renta vivienda unifamiliar (€/m².mes)                                                       -0.70
# Renta vivienda colectiva (€/m².mes)                                                         -0.11
# Nº viviendas en alquiler                                                                    -0.14
# Establecimientos turisticos                                                                 -0.05
# Plazas en sstablecimientos turisticos                                                       -0.06
#
#                                                     Índice de Vulnerabilidad Bienestar Social e Igualdad  \
# Indice de Vulnerabilidad Territorial Agregado                                                    0.77
# Índice de Vulnerabilidad Bienestar Social e Igu...                                               1.00
# Precio vivienda (€/m²)                                                                           0.39
# Renta vivienda unifamiliar (€/m².mes)                                                           -0.95
# Renta vivienda colectiva (€/m².mes)                                                              0.27
# Nº viviendas en alquiler                                                                         0.20
# Establecimientos turisticos                                                                      0.40
# Plazas en sstablecimientos turisticos                                                            0.40
#
#                                                     Precio vivienda (€/m²)  \
# Indice de Vulnerabilidad Territorial Agregado                        -0.04
# Índice de Vulnerabilidad Bienestar Social e Igu...                    0.39
# Precio vivienda (€/m²)                                                1.00
# Renta vivienda unifamiliar (€/m².mes)                                -0.39
# Renta vivienda colectiva (€/m².mes)                                   0.98
# Nº viviendas en alquiler                                              0.95
# Establecimientos turisticos                                           0.99
# Plazas en sstablecimientos turisticos                                 0.99
#
#                                                     Renta vivienda unifamiliar (€/m².mes)  \
# Indice de Vulnerabilidad Territorial Agregado                                       -0.70
# Índice de Vulnerabilidad Bienestar Social e Igu...                                  -0.95
# Precio vivienda (€/m²)                                                              -0.39
# Renta vivienda unifamiliar (€/m².mes)                                                1.00
# Renta vivienda colectiva (€/m².mes)                                                 -0.25
# Nº viviendas en alquiler                                                            -0.17
# Establecimientos turisticos                                                         -0.39
# Plazas en sstablecimientos turisticos                                               -0.39
#
#                                                     Renta vivienda colectiva (€/m².mes)  \
# Indice de Vulnerabilidad Territorial Agregado                                     -0.11
# Índice de Vulnerabilidad Bienestar Social e Igu...                                 0.27
# Precio vivienda (€/m²)                                                             0.98
# Renta vivienda unifamiliar (€/m².mes)                                             -0.25
# Renta vivienda colectiva (€/m².mes)                                                1.00
# Nº viviendas en alquiler                                                           0.99
# Establecimientos turisticos                                                        0.97
# Plazas en sstablecimientos turisticos                                              0.96
#
#                                                     Nº viviendas en alquiler  \
# Indice de Vulnerabilidad Territorial Agregado                          -0.14
# Índice de Vulnerabilidad Bienestar Social e Igu...                      0.20
# Precio vivienda (€/m²)                                                  0.95
# Renta vivienda unifamiliar (€/m².mes)                                  -0.17
# Renta vivienda colectiva (€/m².mes)                                     0.99
# Nº viviendas en alquiler                                                1.00
# Establecimientos turisticos                                             0.96
# Plazas en sstablecimientos turisticos                                   0.95
#
#                                                     Establecimientos turisticos  \
# Indice de Vulnerabilidad Territorial Agregado                             -0.05
# Índice de Vulnerabilidad Bienestar Social e Igu...                         0.40
# Precio vivienda (€/m²)                                                     0.99
# Renta vivienda unifamiliar (€/m².mes)                                     -0.39
# Renta vivienda colectiva (€/m².mes)                                        0.97
# Nº viviendas en alquiler                                                   0.96
# Establecimientos turisticos                                                1.00
# Plazas en sstablecimientos turisticos                                      1.00
#
#                                                     Plazas en sstablecimientos turisticos
# Indice de Vulnerabilidad Territorial Agregado                                       -0.06
# Índice de Vulnerabilidad Bienestar Social e Igu...                                   0.40
# Precio vivienda (€/m²)                                                               0.99
# Renta vivienda unifamiliar (€/m².mes)                                               -0.39
# Renta vivienda colectiva (€/m².mes)                                                  0.96
# Nº viviendas en alquiler                                                             0.95
# Establecimientos turisticos                                                          1.00
# Plazas en sstablecimientos turisticos                                                1.00

# %%
df_total = df_total.sort_values(["Distrito", "Año"])

cols_evolucion = [
    "Establecimientos turisticos",
    "Plazas en sstablecimientos turisticos",
    "Precio vivienda (€/m²)",
    "Precio alquiler €/m² media del año",
    "Indice de Vulnerabilidad Territorial Agregado",
    "Índice de Vulnerabilidad Bienestar Social e Igualdad"
]

for col in cols_evolucion:
    df_total[col + "_var_pct"] = df_total.groupby("Distrito")[col].pct_change() * 100

df_total.head(30)
# Out:
#      Año    Distrito  Establecimientos turisticos  \
# 0   2020      Centro                           48
# 3   2021      Centro                           55
# 6   2022      Centro                           58
# 9   2023      Centro                           59
# 12  2024      Centro                           59
# 1   2020      Tetuán                            4
# 4   2021      Tetuán                            5
# 7   2022      Tetuán                            6
# 10  2023      Tetuán                            9
# 13  2024      Tetuán                           15
# 2   2020  Villaverde                            1
# 5   2021  Villaverde                            1
# 8   2022  Villaverde                            1
# 11  2023  Villaverde                            2
# 14  2024  Villaverde                            3
#
#     Plazas en sstablecimientos turisticos  Nº viviendas en alquiler  \
# 0                                    2643                     18981
# 3                                    3096                     19583
# 6                                    3051                     19945
# 9                                    3109                     20393
# 12                                   3268                     20525
# 1                                     301                     17586
# 4                                     327                     18140
# 7                                     357                     18764
# 10                                    399                     19616
# 13                                    637                     20337
# 2                                       1                      7956
# 5                                       1                      8285
# 8                                       1                      8771
# 11                                     20                      9312
# 14                                     28                      9667
#
#     Nº viviendas en alquiler colectiva  Nº viviendas en alquiler unifamiliar  \
# 0                                18974                                     7
# 3                                19576                                     7
# 6                                19938                                     7
# 9                                20385                                     8
# 12                               20518                                     7
# 1                                17535                                    51
# 4                                18082                                    58
# 7                                18703                                    61
# 10                               19549                                    67
# 13                               20271                                    66
# 2                                 7887                                    69
# 5                                 8215                                    70
# 8                                 8696                                    75
# 11                                9239                                    73
# 14                                9599                                    68
#
#     Renta vivienda colectiva (€/m².mes)  \
# 0                                 15.36
# 3                                 15.32
# 6                                 16.01
# 9                                 16.77
# 12                                17.70
# 1                                 13.82
# 4                                 13.95
# 7                                 14.52
# 10                                15.22
# 13                                16.08
# 2                                  8.65
# 5                                  8.93
# 8                                  9.31
# 11                                 9.72
# 14                                10.26
#
#     Renta vivienda unifamiliar (€/m².mes)  Precio vivienda (€/m²)  \
# 0                                    0.00                 5223.73
# 3                                    0.00                 4935.90
# 6                                    0.00                 5466.32
# 9                                    0.00                 5712.09
# 12                                   0.00                 6268.72
# 1                                   11.44                 3648.00
# 4                                   11.62                 3756.93
# 7                                   12.20                 3955.42
# 10                                  12.52                 4677.48
# 13                                  13.39                 4755.80
# 2                                    8.12                 1749.87
# 5                                    8.42                 1836.69
# 8                                    8.90                 1830.26
# 11                                   9.35                 1900.28
# 14                                   9.90                 2112.72
#
#     Indice de Vulnerabilidad Territorial Agregado  \
# 0                                            5.53
# 3                                            5.57
# 6                                            5.78
# 9                                            5.66
# 12                                           5.89
# 1                                            5.34
# 4                                            5.24
# 7                                            4.89
# 10                                           4.81
# 13                                           4.69
# 2                                            5.66
# 5                                            5.66
# 8                                            5.80
# 11                                           5.76
# 14                                           5.64
#
#     Índice de Vulnerabilidad Bienestar Social e Igualdad  \
# 0                                                5.98
# 3                                                6.56
# 6                                                6.61
# 9                                                6.17
# 12                                               6.45
# 1                                                4.53
# 4                                                4.48
# 7                                                4.09
# 10                                               3.86
# 13                                               3.78
# 2                                                4.87
# 5                                                4.86
# 8                                                5.18
# 11                                               5.02
# 14                                               4.81
#
#     Precio alquiler €/m² media del año  Establecimientos turisticos_var_pct  \
# 0                            18.158333                                  NaN
# 3                            16.375000                            14.583333
# 6                            18.225000                             5.454545
# 9                            20.583333                             1.724138
# 12                           23.791667                             0.000000
# 1                            15.750000                                  NaN
# 4                            14.425000                            25.000000
# 7                            15.658333                            20.000000
# 10                           17.383333                            50.000000
# 13                           19.825000                            66.666667
# 2                            10.950000                                  NaN
# 5                            10.533333                             0.000000
# 8                            11.291667                             0.000000
# 11                           12.358333                           100.000000
# 14                           14.616667                            50.000000
#
#     Plazas en sstablecimientos turisticos_var_pct  \
# 0                                             NaN
# 3                                       17.139614
# 6                                       -1.453488
# 9                                        1.901016
# 12                                       5.114185
# 1                                             NaN
# 4                                        8.637874
# 7                                        9.174312
# 10                                      11.764706
# 13                                      59.649123
# 2                                             NaN
# 5                                        0.000000
# 8                                        0.000000
# 11                                    1900.000000
# 14                                      40.000000
#
#     Precio vivienda (€/m²)_var_pct  \
# 0                              NaN
# 3                        -5.510047
# 6                        10.746166
# 9                         4.496078
# 12                        9.744769
# 1                              NaN
# 4                         2.986020
# 7                         5.283303
# 10                       18.254951
# 13                        1.674406
# 2                              NaN
# 5                         4.961511
# 8                        -0.350086
# 11                        3.825686
# 14                       11.179405
#
#     Precio alquiler €/m² media del año_var_pct  \
# 0                                          NaN
# 3                                    -9.821019
# 6                                    11.297710
# 9                                    12.940101
# 12                                   15.587045
# 1                                          NaN
# 4                                    -8.412698
# 7                                     8.549971
# 10                                   11.016498
# 13                                   14.046021
# 2                                          NaN
# 5                                    -3.805175
# 8                                     7.199367
# 11                                    9.446494
# 14                                   18.273769
#
#     Indice de Vulnerabilidad Territorial Agregado_var_pct  \
# 0                                                 NaN
# 3                                            0.723327
# 6                                            3.770197
# 9                                           -2.076125
# 12                                           4.063604
# 1                                                 NaN
# 4                                           -1.872659
# 7                                           -6.679389
# 10                                          -1.635992
# 13                                          -2.494802
# 2                                                 NaN
# 5                                            0.000000
# 8                                            2.473498
# 11                                          -0.689655
# 14                                          -2.083333
#
#     Índice de Vulnerabilidad Bienestar Social e Igualdad_var_pct
# 0                                                 NaN
# 3                                            9.698997
# 6                                            0.762195
# 9                                           -6.656581
# 12                                           4.538088
# 1                                                 NaN
# 4                                           -1.103753
# 7                                           -8.705357
# 10                                          -5.623472
# 13                                          -2.072539
# 2                                                 NaN
# 5                                           -0.205339
# 8                                            6.584362
# 11                                          -3.088803
# 14                                          -4.183267

# %%
resumen = df_total.groupby("Distrito").agg({
    "Establecimientos turisticos": ["first", "last"],
    "Plazas en sstablecimientos turisticos": ["first", "last"],
    "Precio vivienda (€/m²)": ["first", "last"],
    "Precio alquiler €/m² media del año": ["first", "last"],
    "Indice de Vulnerabilidad Territorial Agregado": ["first", "last"],
    "Índice de Vulnerabilidad Bienestar Social e Igualdad": ["first", "last"]
})

print(resumen)
# Out:
#            Establecimientos turisticos       \
#                                  first last
# Distrito
# Centro                              48   59
# Tetuán                               4   15
# Villaverde                           1    3
#
#            Plazas en sstablecimientos turisticos       Precio vivienda (€/m²)  \
#                                            first  last                  first
# Distrito
# Centro                                      2643  3268                5223.73
# Tetuán                                       301   637                3648.00
# Villaverde                                     1    28                1749.87
#
#                     Precio alquiler €/m² media del año             \
#                last                              first       last
# Distrito
# Centro      6268.72                          18.158333  23.791667
# Tetuán      4755.80                          15.750000  19.825000
# Villaverde  2112.72                          10.950000  14.616667
#
#            Indice de Vulnerabilidad Territorial Agregado        \
#                                                    first  last
# Distrito
# Centro                                              5.53  5.89
# Tetuán                                              5.34  4.69
# Villaverde                                          5.66  5.64
#
#            Índice de Vulnerabilidad Bienestar Social e Igualdad
#                                                           first  last
# Distrito
# Centro                                                   5.98    6.45
# Tetuán                                                   4.53    3.78
# Villaverde                                               4.87    4.81

# %%
df_2020 = df_total[df_total["Año"] == 2020].set_index("Distrito")
df_2024 = df_total[df_total["Año"] == 2024].set_index("Distrito")

variables = [
    "Establecimientos turisticos",
    "Plazas en sstablecimientos turisticos",
    "Precio vivienda (€/m²)",
    "Precio alquiler €/m² media del año",
    "Indice de Vulnerabilidad Territorial Agregado",
    "Índice de Vulnerabilidad Bienestar Social e Igualdad"
]

variacion_2020_2024 = ((df_2024[variables] - df_2020[variables]) / df_2020[variables]) * 100

print(variacion_2020_2024.round(2))
# Out:
#             Establecimientos turisticos  \
# Distrito
# Centro                            22.92
# Tetuán                           275.00
# Villaverde                       200.00
#
#             Plazas en sstablecimientos turisticos  Precio vivienda (€/m²)  \
# Distrito
# Centro                                      23.65                   20.00
# Tetuán                                     111.63                   30.37
# Villaverde                                2700.00                   20.74
#
#             Precio alquiler €/m² media del año  \
# Distrito
# Centro                                   31.02
# Tetuán                                   25.87
# Villaverde                               33.49
#
#             Indice de Vulnerabilidad Territorial Agregado  \
# Distrito
# Centro                                               6.51
# Tetuán                                             -12.17
# Villaverde                                          -0.35
#
#             Índice de Vulnerabilidad Bienestar Social e Igualdad
# Distrito
# Centro                                                   7.86
# Tetuán                                                 -16.56
# Villaverde                                              -1.23

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.lineplot(
    data=df_total,
    x="Año",
    y="Precio alquiler €/m² media del año-",
    hue="Distrito",
    marker="o"
)

plt.title("Evolución del precio del alquiler por distrito")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#       3
#       4 sns.lineplot(
# ----> 5     data=df_total,
#       6     x="Año",
#       7     y="Precio alquiler €/m² media del año-",
#       8     hue="Distrito",
#
# NameError: name 'df_total' is not defined

# %%
sns.lineplot(
    data=df_total,
    x="Año",
    y="Precio vivienda (€/m²)-",
    hue="Distrito",
    marker="o"
)

plt.title("Evolución del precio de vivienda por distrito")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 sns.lineplot(
# ----> 2     data=df_total,
#       3     x="Año",
#       4     y="Precio vivienda (€/m²)-",
#       5     hue="Distrito",
#
# NameError: name 'df_total' is not defined

# %%
sns.lineplot(
    data=df_total,
    x="Año",
    y="Indice de Vulnerabilidad Territorial Agregado-",
    hue="Distrito",
    marker="o"
)

plt.title("Evolución del IVTA por distrito")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 sns.lineplot(
# ----> 2     data=df_total,
#       3     x="Año",
#       4     y="Indice de Vulnerabilidad Territorial Agregado-",
#       5     hue="Distrito",
#
# NameError: name 'df_total' is not defined

# %%
df_total
# Out:
#      Año    Distrito  Establecimientos turisticos  \
# 0   2020      Centro                           48
# 3   2021      Centro                           55
# 6   2022      Centro                           58
# 9   2023      Centro                           59
# 12  2024      Centro                           59
# 1   2020      Tetuán                            4
# 4   2021      Tetuán                            5
# 7   2022      Tetuán                            6
# 10  2023      Tetuán                            9
# 13  2024      Tetuán                           15
# 2   2020  Villaverde                            1
# 5   2021  Villaverde                            1
# 8   2022  Villaverde                            1
# 11  2023  Villaverde                            2
# 14  2024  Villaverde                            3
#
#     Plazas en sstablecimientos turisticos  Nº viviendas en alquiler  \
# 0                                    2643                     18981
# 3                                    3096                     19583
# 6                                    3051                     19945
# 9                                    3109                     20393
# 12                                   3268                     20525
# 1                                     301                     17586
# 4                                     327                     18140
# 7                                     357                     18764
# 10                                    399                     19616
# 13                                    637                     20337
# 2                                       1                      7956
# 5                                       1                      8285
# 8                                       1                      8771
# 11                                     20                      9312
# 14                                     28                      9667
#
#     Nº viviendas en alquiler colectiva  Nº viviendas en alquiler unifamiliar  \
# 0                                18974                                     7
# 3                                19576                                     7
# 6                                19938                                     7
# 9                                20385                                     8
# 12                               20518                                     7
# 1                                17535                                    51
# 4                                18082                                    58
# 7                                18703                                    61
# 10                               19549                                    67
# 13                               20271                                    66
# 2                                 7887                                    69
# 5                                 8215                                    70
# 8                                 8696                                    75
# 11                                9239                                    73
# 14                                9599                                    68
#
#     Renta vivienda colectiva (€/m².mes)  \
# 0                                 15.36
# 3                                 15.32
# 6                                 16.01
# 9                                 16.77
# 12                                17.70
# 1                                 13.82
# 4                                 13.95
# 7                                 14.52
# 10                                15.22
# 13                                16.08
# 2                                  8.65
# 5                                  8.93
# 8                                  9.31
# 11                                 9.72
# 14                                10.26
#
#     Renta vivienda unifamiliar (€/m².mes)  Precio vivienda (€/m²)  \
# 0                                    0.00                 5223.73
# 3                                    0.00                 4935.90
# 6                                    0.00                 5466.32
# 9                                    0.00                 5712.09
# 12                                   0.00                 6268.72
# 1                                   11.44                 3648.00
# 4                                   11.62                 3756.93
# 7                                   12.20                 3955.42
# 10                                  12.52                 4677.48
# 13                                  13.39                 4755.80
# 2                                    8.12                 1749.87
# 5                                    8.42                 1836.69
# 8                                    8.90                 1830.26
# 11                                   9.35                 1900.28
# 14                                   9.90                 2112.72
#
#     Indice de Vulnerabilidad Territorial Agregado  \
# 0                                            5.53
# 3                                            5.57
# 6                                            5.78
# 9                                            5.66
# 12                                           5.89
# 1                                            5.34
# 4                                            5.24
# 7                                            4.89
# 10                                           4.81
# 13                                           4.69
# 2                                            5.66
# 5                                            5.66
# 8                                            5.80
# 11                                           5.76
# 14                                           5.64
#
#     Índice de Vulnerabilidad Bienestar Social e Igualdad  \
# 0                                                5.98
# 3                                                6.56
# 6                                                6.61
# 9                                                6.17
# 12                                               6.45
# 1                                                4.53
# 4                                                4.48
# 7                                                4.09
# 10                                               3.86
# 13                                               3.78
# 2                                                4.87
# 5                                                4.86
# 8                                                5.18
# 11                                               5.02
# 14                                               4.81
#
#     Precio alquiler €/m² media del año  Establecimientos turisticos_var_pct  \
# 0                            18.158333                                  NaN
# 3                            16.375000                            14.583333
# 6                            18.225000                             5.454545
# 9                            20.583333                             1.724138
# 12                           23.791667                             0.000000
# 1                            15.750000                                  NaN
# 4                            14.425000                            25.000000
# 7                            15.658333                            20.000000
# 10                           17.383333                            50.000000
# 13                           19.825000                            66.666667
# 2                            10.950000                                  NaN
# 5                            10.533333                             0.000000
# 8                            11.291667                             0.000000
# 11                           12.358333                           100.000000
# 14                           14.616667                            50.000000
#
#     Plazas en sstablecimientos turisticos_var_pct  \
# 0                                             NaN
# 3                                       17.139614
# 6                                       -1.453488
# 9                                        1.901016
# 12                                       5.114185
# 1                                             NaN
# 4                                        8.637874
# 7                                        9.174312
# 10                                      11.764706
# 13                                      59.649123
# 2                                             NaN
# 5                                        0.000000
# 8                                        0.000000
# 11                                    1900.000000
# 14                                      40.000000
#
#     Precio vivienda (€/m²)_var_pct  \
# 0                              NaN
# 3                        -5.510047
# 6                        10.746166
# 9                         4.496078
# 12                        9.744769
# 1                              NaN
# 4                         2.986020
# 7                         5.283303
# 10                       18.254951
# 13                        1.674406
# 2                              NaN
# 5                         4.961511
# 8                        -0.350086
# 11                        3.825686
# 14                       11.179405
#
#     Precio alquiler €/m² media del año_var_pct  \
# 0                                          NaN
# 3                                    -9.821019
# 6                                    11.297710
# 9                                    12.940101
# 12                                   15.587045
# 1                                          NaN
# 4                                    -8.412698
# 7                                     8.549971
# 10                                   11.016498
# 13                                   14.046021
# 2                                          NaN
# 5                                    -3.805175
# 8                                     7.199367
# 11                                    9.446494
# 14                                   18.273769
#
#     Indice de Vulnerabilidad Territorial Agregado_var_pct  \
# 0                                                 NaN
# 3                                            0.723327
# 6                                            3.770197
# 9                                           -2.076125
# 12                                           4.063604
# 1                                                 NaN
# 4                                           -1.872659
# 7                                           -6.679389
# 10                                          -1.635992
# 13                                          -2.494802
# 2                                                 NaN
# 5                                            0.000000
# 8                                            2.473498
# 11                                          -0.689655
# 14                                          -2.083333
#
#     Índice de Vulnerabilidad Bienestar Social e Igualdad_var_pct
# 0                                                 NaN
# 3                                            9.698997
# 6                                            0.762195
# 9                                           -6.656581
# 12                                           4.538088
# 1                                                 NaN
# 4                                           -1.103753
# 7                                           -8.705357
# 10                                          -5.623472
# 13                                          -2.072539
# 2                                                 NaN
# 5                                           -0.205339
# 8                                            6.584362
# 11                                          -3.088803
# 14                                          -4.183267

# %%
sns.lineplot(
    data=df_total,
    x="Año",
    y="plazas_por_1000_viviendas_alquiler",
    hue="Distrito",
    marker="o"
)

plt.title("Plazas turísticas por cada 1.000 viviendas en alquiler")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[186], line 1
# ----> 1 sns.lineplot(
#       2     data=df_total,
#       3     x="Año",
#       4     y="plazas_por_1000_viviendas_alquiler",
#
# File c:\Users\danie\OneDrive\Escritorio\UNIR\TFM\.venv\Lib\site-packages\seaborn\relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)    481
#     482     # Handle deprecation of ci parameter
#     483     errorbar = _deprecate_ci(errorbar, ci)
# --> 485     p = _LinePlotter(
#     486         data=data,
#     487         variables=dict(
#     488             x=x, y=y, hue=hue, size=size, style=style, units=units, weight=weights
#     489         ),
#     490         estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
#     491         sort=sort, orient=orient, err_style=err_style, err_kws=err_kws,
#     492         legend=legend,
#     493     )
#     495     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     496     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File c:\Users\danie\OneDrive\Escritorio\UNIR\TFM\.venv\Lib\site-packages\seaborn\relational.py:216, in _LinePlotter.__init__(self, data, variables, estimator, n_boot, seed, errorbar, sort, orient, err_style, err_kws, legend)
#     202 def __init__(
#     203     self, *,
#     204     data=None, variables={},
#    (...)    210     # the kind of plot to draw, but for the time being we need to set
#     211     # this information so the SizeMapping can use it
#     212     self._default_size_range = (
#     213         np.r_[.5, 2] * mpl.rcParams["lines.linewidth"]
#     214     )
# --> 216     super().__init__(data=data, variables=variables)
#     218     self.estimator = estimator
#     219     self.errorbar = errorbar
#
# File c:\Users\danie\OneDrive\Escritorio\UNIR\TFM\.venv\Lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File c:\Users\danie\OneDrive\Escritorio\UNIR\TFM\.venv\Lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File c:\Users\danie\OneDrive\Escritorio\UNIR\TFM\.venv\Lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File c:\Users\danie\OneDrive\Escritorio\UNIR\TFM\.venv\Lib\site-packages\seaborn\_core\data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `plazas_por_1000_viviendas_alquiler` for `y`. An entry with this name does not appear in `data`.
